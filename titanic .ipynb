# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv("titanic1.zip")
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
print (data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
# None

# %%
print(data.describe())
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
data.dropna(axis=0, inplace=True)

# %%
data.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
display(data[data['Age']>=30])
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 11            12         1       1
# 21            22         1       2
# ..           ...       ...     ...
# 862          863         1       1
# 867          868         0       1
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 21                               Beesley, Mr. Lawrence    male  34.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
display(data[data['Age']<=30])
# Out:
#      PassengerId  Survived  Pclass                                 Name  \
# 10            11         1       3      Sandstrom, Miss. Marguerite Rut
# 23            24         1       1         Sloper, Mr. William Thompson
# 27            28         0       1       Fortune, Mr. Charles Alexander
# 66            67         1       2         Nye, Mrs. (Elizabeth Ramell)
# 75            76         0       3              Moen, Mr. Sigurd Hansen
# ..           ...       ...     ...                                  ...
# 802          803         1       1  Carter, Master. William Thornton II
# 823          824         1       3                   Moor, Mrs. (Beila)
# 853          854         1       1            Lines, Miss. Mary Conover
# 887          888         1       1         Graham, Miss. Margaret Edith
# 889          890         1       1                Behr, Mr. Karl Howell
#
#         Sex   Age  SibSp  Parch      Ticket     Fare        Cabin Embarked
# ...

# %%
display(data[data['Age']<=50])
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 10            11         1       3
# 21            22         1       2
# 23            24         1       1
# ..           ...       ...     ...
# 867          868         0       1
# 871          872         1       1
# 872          873         0       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 21                               Beesley, Mr. Lawrence    male  34.0      0
# 23                        Sloper, Mr. William Thompson    male  28.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
import matplotlib.pyplot as plt
from matplotlib import style
from matplotlib import figure
style.use('fivethirtyeight')

# %%
display(data[data['Survived']==1])
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 10            11         1       3
# 11            12         1       1
# 21            22         1       2
# ..           ...       ...     ...
# 862          863         1       1
# 871          872         1       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 21                               Beesley, Mr. Lawrence    male  34.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
display(data[data['Pclass']==2])
# Out:
#      PassengerId  Survived  Pclass  \
# 21            22         1       2
# 66            67         1       2
# 123          124         1       2
# 148          149         0       2
# 183          184         1       2
# 193          194         1       2
# 292          293         0       2
# 327          328         1       2
# 340          341         1       2
# 345          346         1       2
# 473          474         1       2
# 516          517         1       2
# 618          619         1       2
# 717          718         1       2
# 772          773         0       2
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 21                          Beesley, Mr. Lawrence    male  34.0      0      0
# 66                   Nye, Mrs. (Elizabeth Ramell)  female  29.0      0      0
# 123                           Webber, Miss. Susan  female  32.5      0      0
# 148      Navratil, Mr. Michel ("Louis M Hoffman")    male  36.5      0      2
# ...

# %%
female=data[data.Sex=='female']

# %%
plt.bar(female['Name'], female['Survived'])
plt.title('titanic')
plt.ylabel('PassengerId')
plt.gcf().set_size_inches(20, 10)
plt.xticks(rotation=90)
plt.show()

# %%
plt.barh(female['Name'], female['Survived'],color='GREEN')
plt.title('titanic')
plt.xlabel('PassengerId')
plt.gcf().set_size_inches(20, 10)
#plt.xticks(rotation=240)
plt.show()

# %%
Name=data['Age'].value_counts().head(10).values
name=data['Age'].value_counts().head(10).index
plt.gcf().set_size_inches(10, 5)
plt.pie(name, labels=name, autopct="%1.1f%%", wedgeprops={'edgecolor':'RED'}, explode=[0.5,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05])
plt.title('titanic')
plt.show()

# %%
plt.bar(data['Pclass'], data['Age'],color=(data['Age']>40).map({True:'#DBB40C', False:'RED'}))
plt.xlabel('Pclass')
plt.ylabel('Age')
plt.gcf().set_size_inches(8,2)
plt.xticks(rotation=90)
plt.show()
